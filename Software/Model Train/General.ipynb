# %% [markdown]
# ### 图神经网络环境配置，参见 https://www.bilibili.com/video/BV1184y1x71H?p=11

# %%
import os
import numpy as np
import pandas as pd
import os
import pandas as pd
from scipy.io import loadmat
import networkx as nx
import matplotlib.pyplot as plt
import torch
from torch_geometric.data import InMemoryDataset, Data
from tqdm import tqdm
from torch_geometric.loader import DataLoader
from sklearn.metrics import precision_score, f1_score, recall_score, accuracy_score
from torch_geometric.nn import TopKPooling,SAGEConv, GCNConv, SAGPooling
from torch_geometric.nn import global_mean_pool as gap, global_max_pool as  gmp
from torch.nn import Linear,BatchNorm1d, ReLU
import torch.nn.functional as F
from imblearn.under_sampling import RandomUnderSampler

device = torch.device("mps" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %% [markdown]
# ## 参数

# %%
epoch_num = 50  # 训练轮数
lr = 0.001      # 学习率
bs = 64         # 批次大小
isCause = True # 是否加入因果关系

dataset_root = '../Data' # 数据存放目录

# %% [markdown]
# ## 因果关系的加入
# 注意：节点必须从0开始标号

# %%
def get_edge_index_and_edge_attr(ex_type):
    # source_nodes->target_nodes对应着一条有向边，而edge_attr为此条有向边的权值,无向图代表两个方向都有边
    source_nodes = [0, 1, 0, 4, 0, 7, 1, 2, 2, 3, 4, 5, 5, 6, 7, 8, 8, 9, 8, 14, 8, 19, 9, 10, 10, 11, 11, 12, 12, 13, 14, 15, 15, 16, 16, 17, 17, 18, 19, 20, 20, 21]
    target_nodes = [1, 0, 4, 0, 7, 0, 2, 1, 3, 2, 5, 4, 6, 5, 8, 7, 9, 8, 14, 8, 19, 8, 10, 9, 11, 10, 12, 11, 13, 12, 15, 14, 16, 15, 17, 16, 18, 17, 20, 19, 21, 20]
    edge_attr = None
    if isCause:
        # one leg stand
        source_nodes = [0, 1, 1, 2, 5, 5, 7, 7, 8 , 14 , 9, 10, 11, 12, 14, 15, 17, 17, 8, 19, 20]
        target_nodes = [4, 0, 2, 3, 4, 6, 0, 8, 9, 8 ,  10, 11, 12, 13, 15, 16, 16, 18, 19, 20, 21]
        edge_attr = None
    edge_index = torch.tensor([source_nodes, target_nodes], dtype=torch.long)
    return edge_index, edge_attr

# %% [markdown]
# ## 数据处理部分
# 注意：如果图结构发生改变，请删除数据根目录/processed/下的缓存文件，以重新进行数据处理

# %%
# 这个类继承自InMemoryDataset，专门处理中小型数据集
class BinaryDataset(InMemoryDataset):
    def __init__(self, root, transform=None, pre_transform=None, pre_filter=None):
        super().__init__(root, transform, pre_transform, pre_filter)
        self.load(self.processed_paths[0])

    @property
    def raw_file_names(self):
        return []
    # 如果根目录下的processed文件夹下已经尤处理好的图数据，则直接读取
    @property
    def processed_file_names(self):
        if isCause:
            return ['cause.dataset']
        else:
            return ['base.dataset',]
    def download(self):
        # Download to `self.raw_dir`.
        pass

    def process(self):
        """
        Load Data Seperate All data in Protective and Non-Prtective Data
        """
        # Assuming the 'Data' folder is in the current working directory
        data_folders = [dataset_root]

        # Initialize lists to store the separated dataframes
        protective_dfs = []
        non_protective_dfs = []

        # Loop through each data folder
        for data_folder in data_folders:
            # List all .mat files in the current data folder
            mat_files = [f for f in os.listdir(data_folder) if f.endswith('.mat')]
            # Load each mat file
            for mat_file in mat_files:
                # Construct the full path to the .mat file
                mat_path = os.path.join(data_folder, mat_file)
                # Load the .mat file
                mat_data = loadmat(mat_path)
                # Convert the data into a pandas dataframe
                df = pd.DataFrame(mat_data['data'])
                # Select only the first 70 columns and the last column (73rd) which contains the behavior label
                df = df.iloc[:, list(range(66)) + [70] + [72]]
                # Split the data based on the protective behavior label
                # Assuming the last column in df is the protective behavior label
                protective_behavior = df.iloc[:, -1]
                protective_df = df[protective_behavior == 1]
                non_protective_df = df[protective_behavior == 0]
                # Append the resulting dataframes to their respective lists
                protective_dfs.append(protective_df)
                non_protective_dfs.append(non_protective_df)

        # Concatenate all protective and non-protective dataframes
        all_protective_data = pd.concat(protective_dfs, axis=0, ignore_index=True)
        all_non_protective_data = pd.concat(non_protective_dfs, axis=0, ignore_index=True)

        # Now `all_protective_data` and `all_non_protective_data` hold the protective and non-protective data respectively
        # You can process these dataframes as needed for your analysis or save them to new .mat files
        # 保护和非保护数据个数 (77298, 68) (437247, 68)
        # 数据合并
        all_data = np.concatenate([all_protective_data,all_non_protective_data],axis=0)
        # 提取运动类型和保护性行为列
        ys = all_data[:,-2:]
        # 将特征列构建为N*V*C的形式，其中N=图个数（一条数据就可以看作一个图），V代表节点个数， C代表每个节点的特征个数
        x = all_data[:,np.newaxis,[0,22,44]]
        for node in range(2, 23):
            x_index = node - 1
            y_index = x_index + 22
            z_index = x_index + 44
            temp = all_data[:,np.newaxis,[x_index,y_index,z_index]]
            x = np.concatenate([x,temp], axis=1)
        # 将边整理为GNN要求的格式，边索引必须从0开始
       
        # 构建数据列表
        data_list = []
        # 一条数据构建为一个图
        for i in range(x.shape[0]):
            y = torch.tensor([ys[i,-1]], dtype=torch.float)   
            # 根据数据所属运动类型获得其拓扑结构
            edge_index, edge_attr = get_edge_index_and_edge_attr(ys[i,-2])
            data = Data(x=torch.tensor(x[i], dtype=torch.float), edge_index=edge_index, edge_attr=edge_attr, y=y)
            data_list.append(data)
        # 将处理后的数据存储至指定根目录下
        data, slices = self.collate(data_list)
        torch.save((data, slices), self.processed_paths[0])
            
        
# 加载并分割数据集      
def load_data_and_split(dataset_root):
    # 数据打乱
    dataset = BinaryDataset(root=dataset_root)
    # 随机打乱
    dataset = dataset.shuffle()
    # 数据划分逻辑
    num_graphs = len(dataset)
    train_size = int(num_graphs * 0.8)
    # train_size = int(num_graphs * 0.01)
    
    # 创建训练集和测试集的子集索引
    train_indices = list(range(train_size))
    test_indices = list(range(train_size, num_graphs))
    
    # 使用torch_geometric.data.Subset来划分数据
    train_dataset = dataset.index_select(train_indices)
    test_dataset = dataset.index_select(test_indices)
    print("isCause:",isCause)
    print("len of train_dataset:",len(train_dataset))
    print("len of test_dataset :",len(test_dataset))
    # 创建DataLoaders
    train_loader = DataLoader(train_dataset, batch_size=bs, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=bs, shuffle=False)
    
    return train_loader, test_loader

train_loader, test_loader =  load_data_and_split(dataset_root)
# Out:
# Processing...
# isCause: True
# len of train_dataset: 411636
# len of test_dataset : 102909
# Done!

# %% [markdown]
# ## 模型定义
# 模块参见文档 https://pytorch-geometric.readthedocs.io/en/latest/

# %%
class Net(torch.nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.conv1 = GCNConv(3,64)
        self.pool1 = TopKPooling(64, ratio=0.8)
        self.conv2 = GCNConv(64,64)
        self.pool2 = TopKPooling(64, ratio=0.8)
        self.conv3 = GCNConv(64,64)
        self.pool3 = TopKPooling(64, ratio=0.8)
        self.lin1 = Linear(64,64)
        self.lin2 = Linear(64,32)
        self.lin3 = Linear(32,1)
        # self.bn1 = BatchNorm1d(64)
        # self.bn2 = BatchNorm1d(32)
        self.act1 = ReLU()
        self.act2 = ReLU()

    
    def forward(self, data):
        x, edge_index, batch, edge_attr = data.x, data.edge_index, data.batch, data.edge_attr

        x = x.clone().detach().requires_grad_(True)
        x = F.relu(self.conv1(x, edge_index, edge_attr))
        # x, edge_index, _, batch, _, _ = self.pool1(x, edge_index, edge_attr, batch)
        x1 = gap(x, batch)
        
        x = F.relu(self.conv2(x, edge_index, edge_attr))
        x, edge_index, _, batch, _, _ = self.pool2(x, edge_index, edge_attr, batch)
        x2 = gap(x, batch)
        
        # x = F.relu(self.conv3(x, edge_index))
        # x, edge_index, _, batch, _, _ = self.pool3(x, edge_index, None, batch)
        # x3 = gap(x, batch)  
        
        x = x1 + x2
        x = self.lin1(x)
        x = self.act1(x)
        x = self.lin2(x)
        x = self.act2(x)
        x = F.dropout(x, p=0.5, training=self.training)
        
        # 输出值为0-1之间 （0为非保护 1为保护）
        x = torch.sigmoid(self.lin3(x)).squeeze(1)
        return x

# %% [markdown]
# ## 模型训练和测试

# %%
def train(train_loader):
    model.train()
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        output = model(data)
        label = data.y.to(device)
        loss = crit(output, label)
        loss.backward()
        optimizer.step()

def test(loader):
    model.eval()
    y_true = []
    y_pred = []

    with torch.no_grad():  # 在评估模式下不计算梯度
        for data in loader:
            data = data.to(device)
            out = model(data)  # 前向传播
            pred = (out >= 0.5).int()

            y_true.extend(data.y.clone().detach().tolist())  # 收集真实标签
            y_pred.extend(pred.clone().detach().tolist())  # 收集预测标签
    
    accuracy = accuracy_score(y_true, y_pred)
    macro_precision = precision_score(y_true, y_pred,  pos_label=1, average='macro') 
    
    f1 = f1_score(y_true, y_pred, pos_label=1)  # Only report results for the class specified by pos_label. 考虑了非平衡
    recall = recall_score(y_true, y_pred, pos_label=1)
    return accuracy, macro_precision, f1, recall

model = Net().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
crit = torch.nn.BCELoss()
for epoch in range(1, epoch_num):
    train(train_loader)
    train_accuracy, train_macro_precision, train_f1, train_recall = test(train_loader)
    test_accuracy,  test_macro_precision,  test_f1 , test_recall  = test(test_loader)
    
    print(f'Epoch: {epoch:03d}  -------------------------- '
          f'\nTrain: accuracy: {train_accuracy:.4f}, Macro Precision: {train_macro_precision:.4f}, F1: {train_f1:.4f}, recall: {train_recall:.4f}  '
          f'\nTest : accuracy: {test_accuracy:.4f}, Macro Precision: {test_macro_precision:.4f}, F1: {test_f1:.4f}, recall: {test_recall:.4f}')
# Out:
# Epoch: 001  --------------------------
# Train: accuracy: 0.8557, Macro Precision: 0.7425, F1: 0.1566, recall: 0.0895
# Test : accuracy: 0.8536, Macro Precision: 0.7479, F1: 0.1602, recall: 0.0916
# Epoch: 002  --------------------------
# Train: accuracy: 0.8668, Macro Precision: 0.8347, F1: 0.2479, recall: 0.1467
# Test : accuracy: 0.8646, Macro Precision: 0.8361, F1: 0.2496, recall: 0.1477
# Epoch: 003  --------------------------
# Train: accuracy: 0.8743, Macro Precision: 0.8424, F1: 0.3335, recall: 0.2101
# Test : accuracy: 0.8721, Macro Precision: 0.8428, F1: 0.3342, recall: 0.2105
# Epoch: 004  --------------------------
# Train: accuracy: 0.8786, Macro Precision: 0.8047, F1: 0.4320, recall: 0.3086
# Test : accuracy: 0.8765, Macro Precision: 0.8038, F1: 0.4342, recall: 0.3108
# Epoch: 005  --------------------------
# Train: accuracy: 0.8853, Macro Precision: 0.8627, F1: 0.4311, recall: 0.2903
# Test : accuracy: 0.8826, Macro Precision: 0.8607, F1: 0.4265, recall: 0.2862
# Epoch: 006  --------------------------
# Train: accuracy: 0.8900, Macro Precision: 0.8533, F1: 0.4846, recall: 0.3454
# Test : accuracy: 0.8883, Macro Precision: 0.8540, F1: 0.4861, recall: 0.3464
# Epoch: 007  --------------------------
# Train: accuracy: 0.8923, Macro Precision: 0.8938, F1: 0.4691, recall: 0.3178
# Test : accuracy: 0.8904, Macro Precision: 0.8927, F1: 0.4697, recall: 0.3183
# Epoch: 008  --------------------------
# Train: accuracy: 0.8959, Macro Precision: 0.8431, F1: 0.5496, recall: 0.4242
# Test : accuracy: 0.8951, Macro Precision: 0.8456, F1: 0.5546, recall: 0.4283
# Epoch: 009  --------------------------
# Train: accuracy: 0.8982, Macro Precision: 0.8240, F1: 0.5986, recall: 0.5071
# Test : accuracy: 0.8972, Macro Precision: 0.8251, F1: 0.6026, recall: 0.5112
# Epoch: 010  --------------------------
# Train: accuracy: 0.9057, Macro Precision: 0.8768, F1: 0.5912, recall: 0.4554
# Test : accuracy: 0.9044, Macro Precision: 0.8763, F1: 0.5944, recall: 0.4591
# Epoch: 011  --------------------------
# Train: accuracy: 0.9036, Macro Precision: 0.8474, F1: 0.6072, recall: 0.4979
# Test : accuracy: 0.9027, Macro Precision: 0.8501, F1: 0.6100, recall: 0.4989
# Epoch: 012  --------------------------
# Train: accuracy: 0.9073, Macro Precision: 0.8773, F1: 0.6022, recall: 0.4690
# Test : accuracy: 0.9056, Macro Precision: 0.8764, F1: 0.6028, recall: 0.4698
# Epoch: 013  --------------------------
# Train: accuracy: 0.9077, Macro Precision: 0.8803, F1: 0.6027, recall: 0.4677
# Test : accuracy: 0.9056, Macro Precision: 0.8781, F1: 0.6012, recall: 0.4666
# Epoch: 014  --------------------------
# Train: accuracy: 0.9090, Macro Precision: 0.8951, F1: 0.5995, recall: 0.4550
# Test : accuracy: 0.9079, Macro Precision: 0.8945, F1: 0.6033, recall: 0.4594
# Epoch: 015  --------------------------
# Train: accuracy: 0.9106, Macro Precision: 0.8732, F1: 0.6303, recall: 0.5091
# Test : accuracy: 0.9100, Macro Precision: 0.8745, F1: 0.6356, recall: 0.5146
# Epoch: 016  --------------------------
# Train: accuracy: 0.9197, Macro Precision: 0.8750, F1: 0.6897, recall: 0.5963
# Test : accuracy: 0.9184, Macro Precision: 0.8745, F1: 0.6911, recall: 0.5982
# Epoch: 017  --------------------------
# Train: accuracy: 0.9122, Macro Precision: 0.8735, F1: 0.6410, recall: 0.5237
# Test : accuracy: 0.9113, Macro Precision: 0.8746, F1: 0.6446, recall: 0.5273
# Epoch: 018  --------------------------
# Train: accuracy: 0.9173, Macro Precision: 0.8980, F1: 0.6538, recall: 0.5221
# Test : accuracy: 0.9150, Macro Precision: 0.8952, F1: 0.6508, recall: 0.5195
# Epoch: 019  --------------------------
# Train: accuracy: 0.9179, Macro Precision: 0.8644, F1: 0.6893, recall: 0.6085
# Test : accuracy: 0.9170, Macro Precision: 0.8665, F1: 0.6903, recall: 0.6066
# Epoch: 020  --------------------------
# Train: accuracy: 0.9108, Macro Precision: 0.8694, F1: 0.6353, recall: 0.5191
# Test : accuracy: 0.9096, Macro Precision: 0.8706, F1: 0.6366, recall: 0.5194
# Epoch: 021  --------------------------
# Train: accuracy: 0.9223, Macro Precision: 0.8849, F1: 0.6972, recall: 0.5973
# Test : accuracy: 0.9215, Macro Precision: 0.8856, F1: 0.6996, recall: 0.5996
# Epoch: 022  --------------------------
# Train: accuracy: 0.9264, Macro Precision: 0.8769, F1: 0.7290, recall: 0.6618
# Test : accuracy: 0.9249, Macro Precision: 0.8763, F1: 0.7285, recall: 0.6608
# Epoch: 023  --------------------------
# Train: accuracy: 0.9217, Macro Precision: 0.8760, F1: 0.7016, recall: 0.6148
# Test : accuracy: 0.9209, Macro Precision: 0.8771, F1: 0.7040, recall: 0.6165
# Epoch: 024  --------------------------
# Train: accuracy: 0.9208, Macro Precision: 0.8762, F1: 0.6958, recall: 0.6048
# Test : accuracy: 0.9199, Macro Precision: 0.8771, F1: 0.6975, recall: 0.6058
# Epoch: 025  --------------------------
# Train: accuracy: 0.9312, Macro Precision: 0.8933, F1: 0.7427, recall: 0.6633
# Test : accuracy: 0.9299, Macro Precision: 0.8925, F1: 0.7429, recall: 0.6639
# Epoch: 026  --------------------------
# Train: accuracy: 0.9282, Macro Precision: 0.8811, F1: 0.7357, recall: 0.6678
# Test : accuracy: 0.9273, Macro Precision: 0.8814, F1: 0.7374, recall: 0.6697
# Epoch: 027  --------------------------
# Train: accuracy: 0.9316, Macro Precision: 0.8982, F1: 0.7409, recall: 0.6538
# Test : accuracy: 0.9315, Macro Precision: 0.9002, F1: 0.7457, recall: 0.6587
# Epoch: 028  --------------------------
# Train: accuracy: 0.9252, Macro Precision: 0.8947, F1: 0.7065, recall: 0.6014
# Test : accuracy: 0.9235, Macro Precision: 0.8939, F1: 0.7050, recall: 0.5992
# Epoch: 029  --------------------------
# Train: accuracy: 0.9331, Macro Precision: 0.8914, F1: 0.7546, recall: 0.6877
# Test : accuracy: 0.9327, Macro Precision: 0.8922, F1: 0.7585, recall: 0.6929
# Epoch: 030  --------------------------
# Train: accuracy: 0.9295, Macro Precision: 0.8851, F1: 0.7396, recall: 0.6691
# Test : accuracy: 0.9278, Macro Precision: 0.8838, F1: 0.7384, recall: 0.6680
# Epoch: 031  --------------------------
# Train: accuracy: 0.9341, Macro Precision: 0.8911, F1: 0.7603, recall: 0.6986
# Test : accuracy: 0.9337, Macro Precision: 0.8928, F1: 0.7634, recall: 0.7011
# Epoch: 032  --------------------------
# Train: accuracy: 0.9365, Macro Precision: 0.8968, F1: 0.7691, recall: 0.7066
# Test : accuracy: 0.9358, Macro Precision: 0.8975, F1: 0.7709, recall: 0.7080
# Epoch: 033  --------------------------
# Train: accuracy: 0.9315, Macro Precision: 0.9014, F1: 0.7379, recall: 0.6447
# Test : accuracy: 0.9305, Macro Precision: 0.9011, F1: 0.7394, recall: 0.6467
# Epoch: 034  --------------------------
# Train: accuracy: 0.9295, Macro Precision: 0.9051, F1: 0.7240, recall: 0.6178
# Test : accuracy: 0.9281, Macro Precision: 0.9046, F1: 0.7232, recall: 0.6164
# Epoch: 035  --------------------------
# Train: accuracy: 0.9312, Macro Precision: 0.8744, F1: 0.7594, recall: 0.7257
# Test : accuracy: 0.9309, Macro Precision: 0.8764, F1: 0.7625, recall: 0.7275
# Epoch: 036  --------------------------
# Train: accuracy: 0.9366, Macro Precision: 0.9018, F1: 0.7657, recall: 0.6928
# Test : accuracy: 0.9360, Macro Precision: 0.9020, F1: 0.7683, recall: 0.6964
# Epoch: 037  --------------------------
# Train: accuracy: 0.9333, Macro Precision: 0.9063, F1: 0.7445, recall: 0.6498
# Test : accuracy: 0.9319, Macro Precision: 0.9066, F1: 0.7435, recall: 0.6469
# Epoch: 038  --------------------------
# Train: accuracy: 0.9308, Macro Precision: 0.8682, F1: 0.7641, recall: 0.7485
# Test : accuracy: 0.9306, Macro Precision: 0.8700, F1: 0.7672, recall: 0.7506
# Epoch: 039  --------------------------
# Train: accuracy: 0.9307, Macro Precision: 0.8795, F1: 0.7519, recall: 0.7014
# Test : accuracy: 0.9295, Macro Precision: 0.8787, F1: 0.7526, recall: 0.7031
# Epoch: 040  --------------------------
# Train: accuracy: 0.9384, Macro Precision: 0.9115, F1: 0.7692, recall: 0.6853
# Test : accuracy: 0.9382, Macro Precision: 0.9130, F1: 0.7727, recall: 0.6889
# Epoch: 041  --------------------------
# Train: accuracy: 0.9367, Macro Precision: 0.8977, F1: 0.7694, recall: 0.7057
# Test : accuracy: 0.9359, Macro Precision: 0.8981, F1: 0.7710, recall: 0.7072
# Epoch: 042  --------------------------
# Train: accuracy: 0.9378, Macro Precision: 0.9093, F1: 0.7673, recall: 0.6851
# Test : accuracy: 0.9368, Macro Precision: 0.9084, F1: 0.7683, recall: 0.6874
# Epoch: 043  --------------------------
# Train: accuracy: 0.9398, Macro Precision: 0.8971, F1: 0.7861, recall: 0.7395
# Test : accuracy: 0.9387, Macro Precision: 0.8963, F1: 0.7868, recall: 0.7414
# Epoch: 044  --------------------------
# Train: accuracy: 0.9390, Macro Precision: 0.8989, F1: 0.7806, recall: 0.7253
# Test : accuracy: 0.9380, Macro Precision: 0.8988, F1: 0.7810, recall: 0.7254
# Epoch: 045  --------------------------
# Train: accuracy: 0.9378, Macro Precision: 0.9061, F1: 0.7695, recall: 0.6934
# Test : accuracy: 0.9377, Macro Precision: 0.9067, F1: 0.7739, recall: 0.6998
# Epoch: 046  --------------------------
# Train: accuracy: 0.9341, Macro Precision: 0.8843, F1: 0.7665, recall: 0.7224
# Test : accuracy: 0.9332, Macro Precision: 0.8848, F1: 0.7669, recall: 0.7213
# Epoch: 047  --------------------------
# Train: accuracy: 0.9378, Macro Precision: 0.9099, F1: 0.7671, recall: 0.6838
# Test : accuracy: 0.9370, Macro Precision: 0.9097, F1: 0.7686, recall: 0.6860
# Epoch: 048  --------------------------
# Train: accuracy: 0.9414, Macro Precision: 0.9130, F1: 0.7839, recall: 0.7097
# Test : accuracy: 0.9414, Macro Precision: 0.9147, F1: 0.7879, recall: 0.7138
# Epoch: 049  --------------------------
# Train: accuracy: 0.9415, Macro Precision: 0.9072, F1: 0.7878, recall: 0.7258
# Test : accuracy: 0.9416, Macro Precision: 0.9083, F1: 0.7927, recall: 0.7326
